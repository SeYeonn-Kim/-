# %%
from bs4 import BeautifulSoup

# %%
page = open("03. test_first.html",'r').read() #읽기옵션 'r' 쓰기는 'w'
soup = BeautifulSoup(page, 'html.parser')
print(soup.prettify()) #prettify()는 들여쓰기 옵션
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Very Simple HTML Code by PinkWink
#   </title>
#  </head>
#  <body>
#   <div>
#    <p class="inner-text first-item" id="first">
#     Happy PinkWink.
#     <a href="http://www.pinkwink.kr" id="pw-link">
#      PinkWink
#     </a>
#    </p>
#    <p class="inner-text second-item">
#     Happy Data Science.
#     <a href="https://www.python.org" id="py-link">
#      Python
#     </a>
#    </p>
#   </div>
#   <p class="outer-text first-item" id="second">
#    <b>
#     Data Science is funny.
#    </b>
#   </p>
#   <p class="outer-text">
#    <b>
#     All I need is Love.
#    </b>
#   </p>
#  </body>
# </html>

# %%
list(soup.children) #한단계 아래에서 포함된 태그를 알고싶으면
# Out:
# ['html',
#  '\n',
#  <html>
#  <head>
#  <title>Very Simple HTML Code by PinkWink</title>
#  </head>
#  <body>
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>
#  </body>
#  </html>]

# %%
html = list(soup.children)[2]
html
# Out:
# <html>
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>
# </html>

# %%
len(list(soup.children)) #저 위의 모든게 요소 하나임
# Out:
# 3

# %%
list(html.children)
# Out:
# ['\n',
#  <head>
#  <title>Very Simple HTML Code by PinkWink</title>
#  </head>,
#  '\n',
#  <body>
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>
#  </body>,
#  '\n']

# %%
body = list(html.children)[3]
body
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
soup.body
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
soup.div #soup.태그 : 그 태그부터 접근
# Out:
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>

# %%
list(body.children)
# Out:
# ['\n',
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>,
#  '\n',
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  '\n',
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>,
#  '\n']

# %%
len(list(body.children))
# Out:
# 7

# %%
soup.find_all('p') #p태그 모두 찾기
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>,
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>,
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
soup.find('p')
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
soup.find_all('p', class_='outer-text') #p태그에서 class이름이 outer-text인 놈들 다 찾기
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
soup.find_all(class_="outer-text") #outer-text를 클래스 이름으로 가지는 것들
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
soup.find_all(id="first")
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>]

# %%
soup.find('p')
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
list(soup.children)
# Out:
# ['html',
#  '\n',
#  <html>
#  <head>
#  <title>Very Simple HTML Code by PinkWink</title>
#  </head>
#  <body>
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>
#  </body>
#  </html>]

# %%
soup.head
# Out:
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>

# %%
soup.head.next_sibling #다음거,,
# Out:
# '\n'

# %%
soup.head.previous_sibling #앞에거,,
# Out:
# '\n'

# %%
soup.head.next_sibling.next_sibling #같은 위치에서 다음거
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
body.p
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
body.p.next_sibling.next_sibling #그다음 p태그
#href는 하이퍼링크
# Out:
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>

# %%
for each_tag in soup.find_all('p'):
    print(each_tag.get_text()) #get_text는 텍스트만 긁어오기
# Out:
#                 Happy PinkWink.
#                 PinkWink
#
#
#                 Happy Data Science.
#                 Python
#
#
#
#                 Data Science is funny.
#
#
#
#
#                 All I need is Love.

# %%
body.get_text()
# Out:
# '\n\n\n                Happy PinkWink.\n                PinkWink\n\n\n                Happy Data Science.\n                Python\n\n\n\n\n                Data Science is funny.\n            \n\n\n\n                All I need is Love.\n            \n\n'

# %%
links = soup.find_all('a') #a 태그만 가져오기
links
# Out:
# [<a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>,
#  <a href="https://www.python.org" id="py-link">Python</a>]

# %%
for each in links:
    href = each['href'] 
    text = each.string #스트링으로 된 부분을 가져옴 get_text처럼
    print(text+'->'+href)
# Out:
# PinkWink->http://www.pinkwink.kr
# Python->https://www.python.org

# %%
body.b.string
# Out:
# '\n                Data Science is funny.\n            '

# %%
body.b.get_text()
# Out:
# '\n                Data Science is funny.\n            '

# %%
import folium #지도 시각화
import pandas as pd
import googlemaps
import numpy as np

# %%
df=pd.read_csv('03. best_sandwiches_list_chicago2.csv', index_col=0)
df.head(5)
# Out:
#                         Cafe               Menu  Price  \
# Rank
# 1                Old Oak Tap                BLT    $10
# 2                  Au Cheval      Fried Bologna     $9
# 3                       Xoco  Woodland Mushroom  $9.50
# 4                  Al’s Deli         Roast Beef  $9.40
# 5     Publican Quality Meats               PB&L    $10
#
#                        Address
# Rank
# 1        2109 W. Chicago Ave.,
# 2         800 W. Randolph St.,
# 3            445 N. Clark St.,
# 4     914 Noyes St., Evanston,
# 5          825 W. Fulton Mkt.,

# %%
gmaps_key="AIzaSyCqu6j4pDr-76XCpPT4CzqaV0Im-Ijk56c"
gmaps = googlemaps.Client(key=gmaps_key)

# %%
from tqdm import tqdm_notebook

# %%
lat = []
lng = []

for n in tqdm_notebook(df.index):
    if df['Address'][n] != 'Multiple': #주소에 multiple 값 안나오는 경우만 검색
        target_name = df['Address'][n]+', '+'Chicago'
        gmaps_output = gmaps.geocode(target_name)
        location_output = gmaps_output[0].get('geometry')
        lat.append(location_output['location']['lat'])
        lng.append(location_output['location']['lng'])
        
    else:
        lat.append(np.nan)
        lng.append(np.nan)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_8436\307326373.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for n in tqdm_notebook(df.index):
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
len(lat), len(lng)
# Out:
# (50, 50)

# %%
df['lat'] = lat
df['lng'] = lng
df.head()
# Out:
#                         Cafe               Menu  Price  \
# Rank
# 1                Old Oak Tap                BLT    $10
# 2                  Au Cheval      Fried Bologna     $9
# 3                       Xoco  Woodland Mushroom  $9.50
# 4                  Al’s Deli         Roast Beef  $9.40
# 5     Publican Quality Meats               PB&L    $10
#
#                        Address        lat        lng
# Rank
# 1        2109 W. Chicago Ave.,  41.895558 -87.679967
# 2         800 W. Randolph St.,  41.884639 -87.647590
# 3            445 N. Clark St.,  41.890523 -87.630783
# 4     914 Noyes St., Evanston,  42.058322 -87.683748
# 5          825 W. Fulton Mkt.,  41.886604 -87.648536

# %%
mapping = folium.Map(location=[df['lat'].mean(), df['lng'].mean()], 
                                      zoom_start=11)
folium.Marker([df['lat'].mean(), df['lng'].mean()], 
                                      popup='center').add_to(mapping)
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
mapping = folium.Map(location=[df['lat'].mean(), df['lng'].mean()], 
                     zoom_start=11)

for n in df.index:
    if df['Address'][n] != 'Multiple':
        folium.Marker([df['lat'][n], df['lng'][n]], 
                                      popup=df['Cafe'][n]).add_to(mapping)

mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from bs4 import BeautifulSoup  
import pandas as pd

# %%
from urllib.request import urlopen

url_base = "http://movie.naver.com/"
url_sub = "movie/sdb/rank/rmovie.naver?sel=cur&date=20220612"

page = urlopen(url_base+url_sub)

soup = BeautifulSoup(page, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image">
# <meta content="네이버영화 " property="me2:post_tag">
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <meta content="랭킹 : 네이버 영화" property="og:title"/>
# <meta content="영화, 영화인, 예매, 박스오피스 랭킹 정보 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&amp;date=20220612" property="og:url"/>
# <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/><!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# ...

# %%
soup.find_all('div', 'tit5')
# Out:
# [<div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=192608" title="범죄도시2">범죄도시2</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=187320" title="씽2게더">씽2게더</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=213733" title="극장판 주술회전 0">극장판 주술회전 0</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=172174" title="어느 가족">어느 가족</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=19335" title="해피 투게더">해피 투게더</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=201073" title="코다">코다</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=10262" title="델마와 루이스">델마와 루이스</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=172113" title="이별의 아침에 약속의 꽃을 장식하자">이별의 아침에 약속의 꽃을 장식하자</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=17059" title="중경삼림">중경삼림</a>
#  </div>,
# ...

# %%
soup.find_all('div', 'tit5')[0]
# Out:
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=192608" title="범죄도시2">범죄도시2</a>
# </div>

# %%
soup.find_all('div', 'tit5')[0].a #a태그만?
# Out:
# <a href="/movie/bi/mi/basic.naver?code=192608" title="범죄도시2">범죄도시2</a>

# %%
soup.find_all('div', 'tit5')[0].a.string
# Out:
# '범죄도시2'

# %%
soup.find_all('td', 'point')
# Out:
# [<td class="point">9.51</td>,
#  <td class="point">9.39</td>,
#  <td class="point">9.25</td>,
#  <td class="point">9.20</td>,
#  <td class="point">9.19</td>,
#  <td class="point">9.13</td>,
#  <td class="point">9.01</td>,
#  <td class="point">8.97</td>,
#  <td class="point">8.90</td>,
#  <td class="point">8.87</td>,
#  <td class="point">8.81</td>,
#  <td class="point">8.75</td>,
#  <td class="point">8.69</td>,
#  <td class="point">8.63</td>,
#  <td class="point">8.62</td>,
#  <td class="point">8.60</td>,
#  <td class="point">8.42</td>,
#  <td class="point">8.30</td>,
#  <td class="point">8.15</td>,
#  <td class="point">8.12</td>,
#  <td class="point">8.11</td>,
#  <td class="point">8.00</td>,
#  <td class="point">7.99</td>,
#  <td class="point">7.95</td>,
#  <td class="point">7.85</td>,
#  <td class="point">7.47</td>,
#  <td class="point">7.33</td>,
#  <td class="point">7.28</td>,
#  <td class="point">7.19</td>,
#  <td class="point">6.51</td>,
#  <td class="point">6.32</td>,
# ...

# %%
len(soup.find_all('td', 'point'))
# Out:
# 35

# %%
soup.find_all('td', 'point')[0].string
# Out:
# '9.51'

# %%
movie_name = [soup.find_all('div', 'tit5')[n].a.string for n in range(0, 35)]
movie_name
# Out:
# ['범죄도시2',
#  '씽2게더',
#  '극장판 주술회전 0',
#  '어느 가족',
#  '해피 투게더',
#  '코다',
#  '델마와 루이스',
#  '이별의 아침에 약속의 꽃을 장식하자',
#  '중경삼림',
#  '그렇게 아버지가 된다',
#  '화양연화',
#  '아메리칸 셰프',
#  '배드 가이즈',
#  '걸어도 걸어도',
#  '라라랜드',
#  '태풍이 지나가고',
#  '드라이브 마이 카',
#  '어나더 라운드',
#  '우연과 상상',
#  '릴리 슈슈의 모든 것',
#  '하나와 앨리스',
#  '원더풀 라이프',
#  '환상의 빛',
#  '밀양',
#  '애프터 양',
#  '디어 에반 핸슨',
#  '닥터 스트레인지: 대혼돈의 멀티버스',
#  '아사코',
#  '그대가 조국',
#  '신비한 동물들과 덤블도어의 비밀',
#  '박쥐',
#  '쥬라기 월드: 도미니언',
#  '브로커',
#  '일진',
#  '서울괴담']

# %%
movie_point = [soup.find_all('td', 'point')[n].string for n in range(0, 35)]
movie_point
# Out:
# ['9.51',
#  '9.39',
#  '9.25',
#  '9.20',
#  '9.19',
#  '9.13',
#  '9.01',
#  '8.97',
#  '8.90',
#  '8.87',
#  '8.81',
#  '8.75',
#  '8.69',
#  '8.63',
#  '8.62',
#  '8.60',
#  '8.42',
#  '8.30',
#  '8.15',
#  '8.12',
#  '8.11',
#  '8.00',
#  '7.99',
#  '7.95',
#  '7.85',
#  '7.47',
#  '7.33',
#  '7.28',
#  '7.19',
#  '6.51',
#  '6.32',
#  '6.19',
#  '5.57',
#  '4.75',
#  '4.23']

# %%
date = pd.date_range('2022-3-1', periods=100, freq='D')
date
# Out:
# DatetimeIndex(['2022-03-01', '2022-03-02', '2022-03-03', '2022-03-04',
#                '2022-03-05', '2022-03-06', '2022-03-07', '2022-03-08',
#                '2022-03-09', '2022-03-10', '2022-03-11', '2022-03-12',
#                '2022-03-13', '2022-03-14', '2022-03-15', '2022-03-16',
#                '2022-03-17', '2022-03-18', '2022-03-19', '2022-03-20',
#                '2022-03-21', '2022-03-22', '2022-03-23', '2022-03-24',
#                '2022-03-25', '2022-03-26', '2022-03-27', '2022-03-28',
#                '2022-03-29', '2022-03-30', '2022-03-31', '2022-04-01',
#                '2022-04-02', '2022-04-03', '2022-04-04', '2022-04-05',
#                '2022-04-06', '2022-04-07', '2022-04-08', '2022-04-09',
#                '2022-04-10', '2022-04-11', '2022-04-12', '2022-04-13',
#                '2022-04-14', '2022-04-15', '2022-04-16', '2022-04-17',
#                '2022-04-18', '2022-04-19', '2022-04-20', '2022-04-21',
# ...

# %%
import urllib
from tqdm import tqdm_notebook

movie_date = []
movie_name = []
movie_point = []

for today in tqdm_notebook(date):
    html = "http://movie.naver.com/" + \
                                    "movie/sdb/rank/rmovie.nhn?sel=cur&date={date}"
    response = urlopen(html.format(date=
                                   urllib.parse.quote(today.strftime('%Y%m%d'))))
    soup = BeautifulSoup(response, "html.parser")
    
    end = len(soup.find_all('td', 'point'))
    
    movie_date.extend([today for n in range(0, end)])
    movie_name.extend([soup.find_all('div', 'tit5')[n].a.string for n in range(0, end)])
    movie_point.extend([soup.find_all('td', 'point')[n].string for n in range(0, end)])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_8436\1859345539.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for today in tqdm_notebook(date):
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
len(movie_date), len(movie_name), len(movie_point)
# Out:
# (3546, 3546, 3546)

# %%
movie = pd.DataFrame({'date':movie_date, 'name':movie_name, 
                                      'point':movie_point})
movie.head()
# Out:
#         date           name point
# 0 2022-03-01            전투왕  9.53
# 1 2022-03-01           씽2게더  9.43
# 2 2022-03-01     극장판 주술회전 0  9.37
# 3 2022-03-01             코다  9.21
# 4 2022-03-01  스파이더맨: 노 웨이 홈  8.87

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3546 entries, 0 to 3545
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3546 non-null   datetime64[ns]
#  1   name    3546 non-null   object
#  2   point   3546 non-null   object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 83.2+ KB

# %%
movie['point'] = movie['point'].astype(float)
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3546 entries, 0 to 3545
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3546 non-null   datetime64[ns]
#  1   name    3546 non-null   object
#  2   point   3546 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 83.2+ KB

# %%
import numpy as np

movie_unique = pd.pivot_table(movie, index=['name'], aggfunc=np.sum)
movie_best = movie_unique.sort_values(by='point', ascending=False)
movie_best.head()
# Out:
#              point
# name
# 극장판 주술회전 0  927.59
# 코다          869.50
# 씽2게더        836.78
# 드라이브 마이 카   786.41
# 화양연화        748.34

# %%
tmp = movie.query('name == ["쥬라기 월드: 도미니언"]')
tmp
# Out:
#            date          name  point
# 3325 2022-06-01  쥬라기 월드: 도미니언   6.54
# 3355 2022-06-02  쥬라기 월드: 도미니언   6.33
# 3387 2022-06-03  쥬라기 월드: 도미니언   6.27
# 3417 2022-06-04  쥬라기 월드: 도미니언   6.26
# 3445 2022-06-05  쥬라기 월드: 도미니언   6.21
# 3474 2022-06-06  쥬라기 월드: 도미니언   6.21
# 3506 2022-06-07  쥬라기 월드: 도미니언   6.20
# 3543 2022-06-08  쥬라기 월드: 도미니언   6.20

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(12,8))
plt.plot(tmp['date'], tmp['point'])
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
movie_best.head(20)
# Out:
#                         point
# name
# 극장판 주술회전 0             927.59
# 코다                     869.50
# 씽2게더                   836.78
# 드라이브 마이 카              786.41
# 화양연화                   748.34
# 어나더 라운드                671.57
# 아비정전                   642.17
# 스파이더맨: 노 웨이 홈          565.43
# 스펜서                    555.30
# 해피 투게더                 532.76
# 중경삼림                   445.03
# 이상한 나라의 수학자            434.02
# 수퍼 소닉2                 422.58
# 킹메이커                   415.70
# 라라랜드                   413.76
# 더 배트맨                  410.79
# 나이트메어 앨리               409.24
# 패왕별희 디 오리지널            400.43
# 날씨의 아이                 398.00
# 루이스 웨인: 사랑을 그린 고양이 화가  391.78

# %%
movie_pivot = pd.pivot_table(movie, index=["date"], columns=['name'], 
                                         values=['point'])
movie_pivot.head()
# Out:
#               point                                                       \
# name       82년생 김지영 가나의 혼인잔치: 언약 개를 훔치는 완벽한 방법 걸어도 걸어도 경계선 고양이를 부탁해 공기살인
# date
# 2022-03-01      NaN          NaN           NaN     NaN NaN     8.81  NaN
# 2022-03-02      NaN          NaN           NaN     NaN NaN      NaN  NaN
# 2022-03-03      NaN          NaN           NaN     NaN NaN      NaN  NaN
# 2022-03-04      NaN          NaN           NaN     NaN NaN      NaN  NaN
# 2022-03-05      NaN          NaN           NaN     NaN NaN      NaN  NaN
#
#                              ...                                              \
# name       광대: 소리꾼  귀향 그녀에게  ... 하나-비 하나와 앨리스 하우스 오브 구찌 하이 스피드! –프리! 스타팅 데이즈
# date                         ...
# 2022-03-01    8.42 NaN  NaN  ...  NaN     NaN      7.91                  NaN
# 2022-03-02    8.42 NaN  NaN  ...  NaN     NaN      7.90                  NaN
# 2022-03-03    8.42 NaN  NaN  ...  NaN     NaN      7.91                  NaN
# ...

# %%
movie_pivot.columns = movie_pivot.columns.droplevel()

# %%
movie_pivot.head()
# Out:
# name        82년생 김지영  가나의 혼인잔치: 언약  개를 훔치는 완벽한 방법  걸어도 걸어도  경계선  고양이를 부탁해  \
# date
# 2022-03-01       NaN           NaN            NaN      NaN  NaN      8.81
# 2022-03-02       NaN           NaN            NaN      NaN  NaN       NaN
# 2022-03-03       NaN           NaN            NaN      NaN  NaN       NaN
# 2022-03-04       NaN           NaN            NaN      NaN  NaN       NaN
# 2022-03-05       NaN           NaN            NaN      NaN  NaN       NaN
#
# name        공기살인  광대: 소리꾼  귀향  그녀에게  ...  하나-비  하나와 앨리스  하우스 오브 구찌  \
# date                                 ...
# 2022-03-01   NaN     8.42 NaN   NaN  ...   NaN      NaN       7.91
# 2022-03-02   NaN     8.42 NaN   NaN  ...   NaN      NaN       7.90
# 2022-03-03   NaN     8.42 NaN   NaN  ...   NaN      NaN       7.91
# 2022-03-04   NaN     8.42 NaN   NaN  ...   NaN      NaN       7.91
# 2022-03-05   NaN     8.42 NaN   NaN  ...   NaN      NaN       7.91
#
# ...

# %%
import platform
from matplotlib import font_manager, rc

path = "c:/Windows/Fonts/malgun.ttf"
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
target_col = ['씽2게더', '라라랜드', '더 배트맨', '수퍼 소닉2']
plt.figure(figsize=(12,6))
plt.plot(movie_pivot[target_col])
plt.legend(target_col, loc='best')
plt.grid()
plt.show()
